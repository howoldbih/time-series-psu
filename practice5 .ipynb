# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in c:\users\ivan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (24.0)
# Downloading plotly-6.6.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 660.6 kB/s eta 0:00:15
#    ---------------------------------------- 0.0/9.9 MB 495.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/9.9 MB 491.5 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/9.9 MB 595.3 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/9.9 MB 554.9 kB/s eta 0:00:18
#     --------------------------------------- 0.2/9.9 MB 538.9 kB/s eta 0:00:19
#     --------------------------------------- 0.2/9.9 MB 620.6 kB/s eta 0:00:16
#     --------------------------------------- 0.2/9.9 MB 627.5 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/9.9 MB 655.4 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/9.9 MB 655.4 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/9.9 MB 553.0 kB/s eta 0:00:18
#    - -------------------------------------- 0.3/9.9 MB 578.5 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/9.9 MB 586.1 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/9.9 MB 606.2 kB/s eta 0:00:16
#    - -------------------------------------- 0.4/9.9 MB 593.2 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/9.9 MB 593.2 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/9.9 MB 593.2 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/9.9 MB 513.9 kB/s eta 0:00:19
#    - -------------------------------------- 0.5/9.9 MB 512.6 kB/s eta 0:00:19
#    - -------------------------------------- 0.5/9.9 MB 528.7 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/9.9 MB 528.7 kB/s eta 0:00:18
#    -- ------------------------------------- 0.5/9.9 MB 491.5 kB/s eta 0:00:20
#    -- ------------------------------------- 0.5/9.9 MB 498.8 kB/s eta 0:00:19
#    -- ------------------------------------- 0.6/9.9 MB 503.4 kB/s eta 0:00:19
#    -- ------------------------------------- 0.6/9.9 MB 503.4 kB/s eta 0:00:19
#    -- ------------------------------------- 0.6/9.9 MB 459.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 459.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 453.0 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 447.2 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 444.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 449.1 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 441.8 kB/s eta 0:00:21
#    -- ------------------------------------- 0.6/9.9 MB 441.8 kB/s eta 0:00:21
#    -- ------------------------------------- 0.7/9.9 MB 423.6 kB/s eta 0:00:22
#    -- ------------------------------------- 0.7/9.9 MB 420.0 kB/s eta 0:00:22
#    -- ------------------------------------- 0.7/9.9 MB 418.1 kB/s eta 0:00:23
#    -- ------------------------------------- 0.7/9.9 MB 418.8 kB/s eta 0:00:22
#    -- ------------------------------------- 0.7/9.9 MB 417.0 kB/s eta 0:00:23
#    --- ------------------------------------ 0.7/9.9 MB 421.3 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 420.1 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 422.4 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 422.4 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 422.4 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 409.6 kB/s eta 0:00:23
#    --- ------------------------------------ 0.9/9.9 MB 412.2 kB/s eta 0:00:22
#    --- ------------------------------------ 0.9/9.9 MB 415.7 kB/s eta 0:00:22
#    --- ------------------------------------ 0.9/9.9 MB 415.7 kB/s eta 0:00:22
#    --- ------------------------------------ 0.9/9.9 MB 399.7 kB/s eta 0:00:23
#    --- ------------------------------------ 0.9/9.9 MB 403.4 kB/s eta 0:00:23
#    --- ------------------------------------ 0.9/9.9 MB 406.7 kB/s eta 0:00:23
#    --- ------------------------------------ 0.9/9.9 MB 400.3 kB/s eta 0:00:23
#    --- ------------------------------------ 1.0/9.9 MB 403.7 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.0/9.9 MB 403.4 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.0/9.9 MB 406.4 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.0/9.9 MB 402.9 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.0/9.9 MB 403.7 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.1/9.9 MB 404.3 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.1/9.9 MB 401.0 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.1/9.9 MB 412.9 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.1/9.9 MB 415.7 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.2/9.9 MB 415.1 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.2/9.9 MB 414.1 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.2/9.9 MB 419.3 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.2/9.9 MB 420.5 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.3/9.9 MB 422.1 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.3/9.9 MB 425.7 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.3/9.9 MB 424.7 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.4/9.9 MB 429.3 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.4/9.9 MB 428.3 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.4/9.9 MB 429.4 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.4/9.9 MB 431.7 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.4/9.9 MB 434.8 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.5/9.9 MB 437.9 kB/s eta 0:00:20
#    ------ --------------------------------- 1.5/9.9 MB 443.9 kB/s eta 0:00:19
#    ------ --------------------------------- 1.6/9.9 MB 447.8 kB/s eta 0:00:19
#    ------ --------------------------------- 1.6/9.9 MB 453.5 kB/s eta 0:00:19
#    ------ --------------------------------- 1.6/9.9 MB 458.2 kB/s eta 0:00:19
#    ------ --------------------------------- 1.7/9.9 MB 464.4 kB/s eta 0:00:18
#    ------ --------------------------------- 1.7/9.9 MB 466.9 kB/s eta 0:00:18
#    ------- -------------------------------- 1.7/9.9 MB 471.3 kB/s eta 0:00:18
#    ------- -------------------------------- 1.8/9.9 MB 477.2 kB/s eta 0:00:18
#    ------- -------------------------------- 1.8/9.9 MB 479.4 kB/s eta 0:00:17
#    ------- -------------------------------- 1.9/9.9 MB 483.5 kB/s eta 0:00:17
#    ------- -------------------------------- 1.9/9.9 MB 490.9 kB/s eta 0:00:17
#    ------- -------------------------------- 1.9/9.9 MB 492.9 kB/s eta 0:00:17
#    -------- ------------------------------- 2.0/9.9 MB 497.9 kB/s eta 0:00:16
#    -------- ------------------------------- 2.0/9.9 MB 501.8 kB/s eta 0:00:16
#    -------- ------------------------------- 2.0/9.9 MB 503.5 kB/s eta 0:00:16
#    -------- ------------------------------- 2.1/9.9 MB 505.2 kB/s eta 0:00:16
#    -------- ------------------------------- 2.1/9.9 MB 511.9 kB/s eta 0:00:16
#    -------- ------------------------------- 2.2/9.9 MB 513.6 kB/s eta 0:00:16
#    -------- ------------------------------- 2.2/9.9 MB 517.6 kB/s eta 0:00:15
#    --------- ------------------------------ 2.2/9.9 MB 521.4 kB/s eta 0:00:15
#    --------- ------------------------------ 2.3/9.9 MB 522.9 kB/s eta 0:00:15
#    --------- ------------------------------ 2.3/9.9 MB 529.0 kB/s eta 0:00:15
#    --------- ------------------------------ 2.4/9.9 MB 530.3 kB/s eta 0:00:15
#    --------- ------------------------------ 2.4/9.9 MB 533.5 kB/s eta 0:00:15
#    --------- ------------------------------ 2.4/9.9 MB 534.8 kB/s eta 0:00:15
#    --------- ------------------------------ 2.5/9.9 MB 538.7 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.5/9.9 MB 539.9 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.5/9.9 MB 542.8 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.6/9.9 MB 546.2 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.6/9.9 MB 542.9 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.6/9.9 MB 548.3 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.7/9.9 MB 547.2 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.7/9.9 MB 550.3 kB/s eta 0:00:14
#    ----------- ---------------------------- 2.7/9.9 MB 553.4 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.8/9.9 MB 552.7 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.8/9.9 MB 555.3 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.8/9.9 MB 556.3 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.9/9.9 MB 558.8 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.9/9.9 MB 560.1 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.9/9.9 MB 562.9 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.0/9.9 MB 563.5 kB/s eta 0:00:13
#    ------------ --------------------------- 3.0/9.9 MB 562.6 kB/s eta 0:00:13
#    ------------ --------------------------- 3.0/9.9 MB 565.0 kB/s eta 0:00:13
#    ------------ --------------------------- 3.0/9.9 MB 563.9 kB/s eta 0:00:13
#    ------------ --------------------------- 3.1/9.9 MB 568.5 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/9.9 MB 567.6 kB/s eta 0:00:12
#    ------------ --------------------------- 3.2/9.9 MB 569.9 kB/s eta 0:00:12
#    ------------ --------------------------- 3.2/9.9 MB 572.6 kB/s eta 0:00:12
#    ------------- -------------------------- 3.2/9.9 MB 573.2 kB/s eta 0:00:12
#    ------------- -------------------------- 3.3/9.9 MB 575.4 kB/s eta 0:00:12
#    ------------- -------------------------- 3.3/9.9 MB 576.5 kB/s eta 0:00:12
#    ------------- -------------------------- 3.3/9.9 MB 577.2 kB/s eta 0:00:12
#    ------------- -------------------------- 3.4/9.9 MB 579.2 kB/s eta 0:00:12
#    ------------- -------------------------- 3.4/9.9 MB 581.7 kB/s eta 0:00:12
#    ------------- -------------------------- 3.4/9.9 MB 582.0 kB/s eta 0:00:12
#    ------------- -------------------------- 3.4/9.9 MB 582.0 kB/s eta 0:00:12
#    ------------- -------------------------- 3.5/9.9 MB 576.7 kB/s eta 0:00:12
#    -------------- ------------------------- 3.5/9.9 MB 578.6 kB/s eta 0:00:12
#    -------------- ------------------------- 3.5/9.9 MB 576.2 kB/s eta 0:00:12
#    -------------- ------------------------- 3.5/9.9 MB 576.8 kB/s eta 0:00:12
#    -------------- ------------------------- 3.6/9.9 MB 579.0 kB/s eta 0:00:11
#    -------------- ------------------------- 3.6/9.9 MB 579.6 kB/s eta 0:00:11
#    -------------- ------------------------- 3.6/9.9 MB 580.1 kB/s eta 0:00:11
#    -------------- ------------------------- 3.7/9.9 MB 580.8 kB/s eta 0:00:11
#    --------------- ------------------------ 3.7/9.9 MB 582.9 kB/s eta 0:00:11
#    --------------- ------------------------ 3.7/9.9 MB 583.2 kB/s eta 0:00:11
#    --------------- ------------------------ 3.8/9.9 MB 582.4 kB/s eta 0:00:11
#    --------------- ------------------------ 3.8/9.9 MB 584.3 kB/s eta 0:00:11
#    --------------- ------------------------ 3.8/9.9 MB 584.3 kB/s eta 0:00:11
#    --------------- ------------------------ 3.8/9.9 MB 582.2 kB/s eta 0:00:11
#    --------------- ------------------------ 3.8/9.9 MB 582.2 kB/s eta 0:00:11
#    --------------- ------------------------ 3.9/9.9 MB 578.8 kB/s eta 0:00:11
#    --------------- ------------------------ 3.9/9.9 MB 580.9 kB/s eta 0:00:11
#    --------------- ------------------------ 4.0/9.9 MB 581.4 kB/s eta 0:00:11
#    ---------------- ----------------------- 4.0/9.9 MB 583.3 kB/s eta 0:00:11
#    ---------------- ----------------------- 4.0/9.9 MB 583.7 kB/s eta 0:00:11
#    ---------------- ----------------------- 4.1/9.9 MB 585.8 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.1/9.9 MB 586.2 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.1/9.9 MB 583.7 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.1/9.9 MB 585.8 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.2/9.9 MB 587.4 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.2/9.9 MB 586.4 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.2/9.9 MB 586.4 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.2/9.9 MB 584.3 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.3/9.9 MB 584.9 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.3/9.9 MB 584.1 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.3/9.9 MB 585.8 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.3/9.9 MB 586.1 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.4/9.9 MB 584.0 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.4/9.9 MB 585.7 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.4/9.9 MB 585.0 kB/s eta 0:00:10
#    ------------------ --------------------- 4.5/9.9 MB 585.4 kB/s eta 0:00:10
#    ------------------ --------------------- 4.5/9.9 MB 585.5 kB/s eta 0:00:10
#    ------------------ --------------------- 4.5/9.9 MB 586.2 kB/s eta 0:00:10
#    ------------------ --------------------- 4.5/9.9 MB 587.7 kB/s eta 0:00:10
#    ------------------ --------------------- 4.6/9.9 MB 586.7 kB/s eta 0:00:10
#    ------------------ --------------------- 4.6/9.9 MB 586.1 kB/s eta 0:00:10
#    ------------------ --------------------- 4.6/9.9 MB 587.6 kB/s eta 0:00:09
#    ------------------ --------------------- 4.6/9.9 MB 587.6 kB/s eta 0:00:09
#    ------------------ --------------------- 4.7/9.9 MB 583.4 kB/s eta 0:00:10
#    ------------------ --------------------- 4.7/9.9 MB 585.0 kB/s eta 0:00:09
#    ------------------- -------------------- 4.7/9.9 MB 584.3 kB/s eta 0:00:09
#    ------------------- -------------------- 4.8/9.9 MB 584.7 kB/s eta 0:00:09
#    ------------------- -------------------- 4.8/9.9 MB 587.6 kB/s eta 0:00:09
#    ------------------- -------------------- 4.8/9.9 MB 587.9 kB/s eta 0:00:09
#    ------------------- -------------------- 4.9/9.9 MB 589.6 kB/s eta 0:00:09
#    ------------------- -------------------- 4.9/9.9 MB 588.6 kB/s eta 0:00:09
#    ------------------- -------------------- 4.9/9.9 MB 586.6 kB/s eta 0:00:09
#    -------------------- ------------------- 5.0/9.9 MB 589.4 kB/s eta 0:00:09
#    -------------------- ------------------- 5.0/9.9 MB 588.5 kB/s eta 0:00:09
#    -------------------- ------------------- 5.0/9.9 MB 587.8 kB/s eta 0:00:09
#    -------------------- ------------------- 5.0/9.9 MB 590.6 kB/s eta 0:00:09
#    -------------------- ------------------- 5.0/9.9 MB 590.6 kB/s eta 0:00:09
#    -------------------- ------------------- 5.1/9.9 MB 590.1 kB/s eta 0:00:09
#    -------------------- ------------------- 5.1/9.9 MB 590.2 kB/s eta 0:00:09
#    -------------------- ------------------- 5.1/9.9 MB 590.2 kB/s eta 0:00:09
#    -------------------- ------------------- 5.1/9.9 MB 586.3 kB/s eta 0:00:09
#    -------------------- ------------------- 5.2/9.9 MB 588.9 kB/s eta 0:00:09
#    --------------------- ------------------ 5.2/9.9 MB 588.2 kB/s eta 0:00:08
#    --------------------- ------------------ 5.3/9.9 MB 588.7 kB/s eta 0:00:08
#    --------------------- ------------------ 5.3/9.9 MB 589.0 kB/s eta 0:00:08
#    --------------------- ------------------ 5.3/9.9 MB 590.3 kB/s eta 0:00:08
#    --------------------- ------------------ 5.3/9.9 MB 588.5 kB/s eta 0:00:08
#    --------------------- ------------------ 5.4/9.9 MB 589.9 kB/s eta 0:00:08
#    --------------------- ------------------ 5.4/9.9 MB 589.1 kB/s eta 0:00:08
#    --------------------- ------------------ 5.4/9.9 MB 591.7 kB/s eta 0:00:08
#    --------------------- ------------------ 5.4/9.9 MB 589.8 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.5/9.9 MB 591.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.5/9.9 MB 592.6 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.6/9.9 MB 593.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.6/9.9 MB 594.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.6/9.9 MB 592.5 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.7/9.9 MB 595.0 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.7/9.9 MB 595.0 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.7/9.9 MB 592.4 kB/s eta 0:00:08
#    ----------------------- ---------------- 5.7/9.9 MB 593.7 kB/s eta 0:00:08
#    ----------------------- ---------------- 5.8/9.9 MB 594.1 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/9.9 MB 595.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/9.9 MB 595.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/9.9 MB 595.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.8/9.9 MB 591.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.9/9.9 MB 590.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.9/9.9 MB 592.7 kB/s eta 0:00:07
#    ------------------------ --------------- 5.9/9.9 MB 593.0 kB/s eta 0:00:07
#    ------------------------ --------------- 5.9/9.9 MB 593.0 kB/s eta 0:00:07
#    ------------------------ --------------- 6.0/9.9 MB 591.6 kB/s eta 0:00:07
#    ------------------------ --------------- 6.0/9.9 MB 592.7 kB/s eta 0:00:07
#    ------------------------ --------------- 6.1/9.9 MB 593.1 kB/s eta 0:00:07
#    ------------------------ --------------- 6.1/9.9 MB 593.1 kB/s eta 0:00:07
#    ------------------------ --------------- 6.1/9.9 MB 589.6 kB/s eta 0:00:07
#    ------------------------ --------------- 6.1/9.9 MB 589.9 kB/s eta 0:00:07
#    ------------------------ --------------- 6.1/9.9 MB 588.2 kB/s eta 0:00:07
#    ------------------------ --------------- 6.2/9.9 MB 589.5 kB/s eta 0:00:07
#    ------------------------ --------------- 6.2/9.9 MB 588.8 kB/s eta 0:00:07
#    ------------------------- -------------- 6.2/9.9 MB 588.1 kB/s eta 0:00:07
#    ------------------------- -------------- 6.2/9.9 MB 589.3 kB/s eta 0:00:07
#    ------------------------- -------------- 6.3/9.9 MB 588.8 kB/s eta 0:00:07
#    ------------------------- -------------- 6.3/9.9 MB 589.1 kB/s eta 0:00:07
#    ------------------------- -------------- 6.3/9.9 MB 589.3 kB/s eta 0:00:07
#    ------------------------- -------------- 6.3/9.9 MB 588.7 kB/s eta 0:00:07
#    ------------------------- -------------- 6.4/9.9 MB 589.8 kB/s eta 0:00:07
#    ------------------------- -------------- 6.4/9.9 MB 590.1 kB/s eta 0:00:06
#    ------------------------- -------------- 6.4/9.9 MB 590.1 kB/s eta 0:00:06
#    ------------------------- -------------- 6.4/9.9 MB 586.1 kB/s eta 0:00:06
#    -------------------------- ------------- 6.5/9.9 MB 587.2 kB/s eta 0:00:06
#    -------------------------- ------------- 6.5/9.9 MB 588.3 kB/s eta 0:00:06
#    -------------------------- ------------- 6.5/9.9 MB 588.3 kB/s eta 0:00:06
#    -------------------------- ------------- 6.5/9.9 MB 584.4 kB/s eta 0:00:06
#    -------------------------- ------------- 6.5/9.9 MB 584.7 kB/s eta 0:00:06
#    -------------------------- ------------- 6.6/9.9 MB 585.8 kB/s eta 0:00:06
#    -------------------------- ------------- 6.6/9.9 MB 585.8 kB/s eta 0:00:06
#    -------------------------- ------------- 6.6/9.9 MB 582.1 kB/s eta 0:00:06
#    -------------------------- ------------- 6.6/9.9 MB 583.3 kB/s eta 0:00:06
#    -------------------------- ------------- 6.7/9.9 MB 583.6 kB/s eta 0:00:06
#    -------------------------- ------------- 6.7/9.9 MB 583.6 kB/s eta 0:00:06
#    -------------------------- ------------- 6.7/9.9 MB 583.6 kB/s eta 0:00:06
#    --------------------------- ------------ 6.7/9.9 MB 581.7 kB/s eta 0:00:06
#    --------------------------- ------------ 6.8/9.9 MB 582.8 kB/s eta 0:00:06
#    --------------------------- ------------ 6.8/9.9 MB 582.8 kB/s eta 0:00:06
#    --------------------------- ------------ 6.8/9.9 MB 579.9 kB/s eta 0:00:06
#    --------------------------- ------------ 6.8/9.9 MB 579.5 kB/s eta 0:00:06
#    --------------------------- ------------ 6.8/9.9 MB 580.5 kB/s eta 0:00:06
#    --------------------------- ------------ 6.9/9.9 MB 580.8 kB/s eta 0:00:06
#    --------------------------- ------------ 6.9/9.9 MB 580.8 kB/s eta 0:00:06
#    --------------------------- ------------ 6.9/9.9 MB 578.0 kB/s eta 0:00:06
#    --------------------------- ------------ 6.9/9.9 MB 578.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 7.0/9.9 MB 579.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 7.0/9.9 MB 579.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 7.0/9.9 MB 578.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 7.0/9.9 MB 578.6 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.1/9.9 MB 579.6 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.1/9.9 MB 580.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.1/9.9 MB 581.2 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.2/9.9 MB 581.4 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.2/9.9 MB 583.3 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.2/9.9 MB 583.6 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.3/9.9 MB 584.7 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.3/9.9 MB 585.0 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.4/9.9 MB 586.8 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.4/9.9 MB 585.5 kB/s eta 0:00:05
#    ------------------------------ --------- 7.4/9.9 MB 588.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.5/9.9 MB 587.6 kB/s eta 0:00:05
#    ------------------------------ --------- 7.5/9.9 MB 586.2 kB/s eta 0:00:05
#    ------------------------------ --------- 7.5/9.9 MB 588.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.6/9.9 MB 587.6 kB/s eta 0:00:05
#    ------------------------------ --------- 7.6/9.9 MB 587.6 kB/s eta 0:00:05
#    ------------------------------ --------- 7.6/9.9 MB 587.3 kB/s eta 0:00:04
#    ------------------------------ --------- 7.6/9.9 MB 588.2 kB/s eta 0:00:04
#    ------------------------------ --------- 7.7/9.9 MB 587.0 kB/s eta 0:00:04
#    ------------------------------- -------- 7.7/9.9 MB 589.5 kB/s eta 0:00:04
#    ------------------------------- -------- 7.7/9.9 MB 588.2 kB/s eta 0:00:04
#    ------------------------------- -------- 7.8/9.9 MB 589.9 kB/s eta 0:00:04
#    ------------------------------- -------- 7.8/9.9 MB 590.2 kB/s eta 0:00:04
#    ------------------------------- -------- 7.8/9.9 MB 591.2 kB/s eta 0:00:04
#    ------------------------------- -------- 7.9/9.9 MB 591.4 kB/s eta 0:00:04
#    ------------------------------- -------- 7.9/9.9 MB 592.5 kB/s eta 0:00:04
#    -------------------------------- ------- 7.9/9.9 MB 592.6 kB/s eta 0:00:04
#    -------------------------------- ------- 8.0/9.9 MB 592.1 kB/s eta 0:00:04
#    -------------------------------- ------- 8.0/9.9 MB 593.9 kB/s eta 0:00:04
#    -------------------------------- ------- 8.0/9.9 MB 593.9 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 593.5 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 594.3 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/9.9 MB 593.2 kB/s eta 0:00:04
#    -------------------------------- ------- 8.2/9.9 MB 594.1 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 593.6 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 594.4 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 594.4 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 590.5 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 590.5 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 590.5 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 590.5 kB/s eta 0:00:03
#    --------------------------------- ------ 8.2/9.9 MB 590.5 kB/s eta 0:00:03
#    --------------------------------- ------ 8.3/9.9 MB 582.9 kB/s eta 0:00:03
#    --------------------------------- ------ 8.3/9.9 MB 583.8 kB/s eta 0:00:03
#    --------------------------------- ------ 8.3/9.9 MB 584.1 kB/s eta 0:00:03
#    --------------------------------- ------ 8.3/9.9 MB 584.3 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/9.9 MB 585.3 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/9.9 MB 584.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.4/9.9 MB 585.7 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.5/9.9 MB 585.9 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.5/9.9 MB 586.9 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.6/9.9 MB 587.7 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.6/9.9 MB 587.2 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.6/9.9 MB 586.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.6/9.9 MB 587.7 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.9 MB 588.7 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.9 MB 588.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.9 MB 587.7 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.9 MB 588.4 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.8/9.9 MB 588.8 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.8/9.9 MB 588.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.8/9.9 MB 589.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/9.9 MB 590.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/9.9 MB 589.5 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 589.2 kB/s eta 0:00:02
#    ------------------------------------ --- 9.0/9.9 MB 589.9 kB/s eta 0:00:02
#    ------------------------------------ --- 9.0/9.9 MB 589.9 kB/s eta 0:00:02
#    ------------------------------------ --- 9.0/9.9 MB 586.4 kB/s eta 0:00:02
#    ------------------------------------ --- 9.0/9.9 MB 586.4 kB/s eta 0:00:02
#    ------------------------------------ --- 9.0/9.9 MB 585.5 kB/s eta 0:00:02
#    ------------------------------------ --- 9.1/9.9 MB 586.3 kB/s eta 0:00:02
#    ------------------------------------ --- 9.1/9.9 MB 585.9 kB/s eta 0:00:02
#    ------------------------------------ --- 9.1/9.9 MB 586.0 kB/s eta 0:00:02
#    ------------------------------------ --- 9.1/9.9 MB 586.9 kB/s eta 0:00:02
#    ------------------------------------ --- 9.1/9.9 MB 586.9 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/9.9 MB 585.3 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 585.6 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 585.7 kB/s eta 0:00:02
#    ------------------------------------- -- 9.3/9.9 MB 586.6 kB/s eta 0:00:02
#    ------------------------------------- -- 9.3/9.9 MB 586.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.3/9.9 MB 586.4 kB/s eta 0:00:01
#    ------------------------------------- -- 9.4/9.9 MB 587.9 kB/s eta 0:00:01
#    ------------------------------------- -- 9.4/9.9 MB 587.4 kB/s eta 0:00:01
#    ------------------------------------- -- 9.4/9.9 MB 586.9 kB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 587.8 kB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 588.0 kB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 588.2 kB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 589.1 kB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 589.8 kB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 589.5 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/9.9 MB 590.2 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 589.8 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 591.2 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 591.3 kB/s eta 0:00:01
#    ---------------------------------------  9.8/9.9 MB 590.9 kB/s eta 0:00:01
#    ---------------------------------------  9.8/9.9 MB 591.7 kB/s eta 0:00:01
#    ---------------------------------------  9.8/9.9 MB 591.3 kB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 591.5 kB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 591.0 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 590.5 kB/s eta 0:00:00
# Downloading narwhals-2.18.1-py3-none-any.whl (444 kB)
#    ---------------------------------------- 0.0/445.0 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/445.0 kB 640.0 kB/s eta 0:00:01
#    ----- --------------------------------- 61.4/445.0 kB 812.7 kB/s eta 0:00:01
#    -------- ------------------------------ 92.2/445.0 kB 744.7 kB/s eta 0:00:01
#    ---------- --------------------------- 122.9/445.0 kB 717.5 kB/s eta 0:00:01
#    ------------- ------------------------ 153.6/445.0 kB 706.2 kB/s eta 0:00:01
#    ---------------- --------------------- 194.6/445.0 kB 737.3 kB/s eta 0:00:01
#    ------------------- ------------------ 225.3/445.0 kB 724.0 kB/s eta 0:00:01
#    --------------------- ---------------- 256.0/445.0 kB 714.4 kB/s eta 0:00:01
#    ----------------------- -------------- 276.5/445.0 kB 739.6 kB/s eta 0:00:01
#    --------------------------- ---------- 317.4/445.0 kB 701.4 kB/s eta 0:00:01
#    ------------------------------ ------- 358.4/445.0 kB 717.9 kB/s eta 0:00:01
#    --------------------------------- ---- 389.1/445.0 kB 712.2 kB/s eta 0:00:01
#    ---------------------------------- --- 409.6/445.0 kB 709.3 kB/s eta 0:00:01
#    -------------------------------------- 445.0/445.0 kB 695.5 kB/s eta 0:00:00
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.18.1 plotly-6.6.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Ivan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from numpy import asarray

# %%
# аналогичным образом загружаем данные о пассажирах
passengers = pd.read_csv('D:\Downloads\Telegram Desktop\practice5 (2)\data\passengers.csv')
# неподходящий формат данных приводим к тому, с которым Pandas может работать
passengers['Month'] = pd.to_datetime(passengers['Month'])
# также устанавливаем индекс и сортируем
df = passengers.set_index('Month').sort_index()

# %%
df
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# ## Предсказание временного ряда с помощью деревьев

# %% [markdown]
# Попробуем обычное дерево решений и случайный лес, а потом сравним результаты

# %%
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
cols
# Out:
# [            Passengers
#  Month
#  1949-01-01         NaN
#  1949-02-01       112.0
#  1949-03-01       118.0
#  1949-04-01       132.0
#  1949-05-01       129.0
#  ...                ...
#  1960-08-01       622.0
#  1960-09-01       606.0
#  1960-10-01       508.0
#  1960-11-01       461.0
#  1960-12-01       390.0
#
#  [144 rows x 1 columns]]

# %%
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
for i in range(0, 1):
    cols.append(df.shift(-i))
cols
# Out:
# [            Passengers
#  Month
#  1949-01-01         NaN
#  1949-02-01       112.0
#  1949-03-01       118.0
#  1949-04-01       132.0
#  1949-05-01       129.0
#  ...                ...
#  1960-08-01       622.0
#  1960-09-01       606.0
#  1960-10-01       508.0
#  1960-11-01       461.0
#  1960-12-01       390.0
#
#  [144 rows x 1 columns],
#              Passengers
#  Month
#  1949-01-01         112
#  1949-02-01         118
#  1949-03-01         132
#  1949-04-01         129
#  1949-05-01         121
#  ...                ...
#  1960-08-01         606
#  1960-09-01         508
#  1960-10-01         461
#  1960-11-01         390
#  1960-12-01         432
#
#  [144 rows x 1 columns]]

# %%
agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)
agg
# Out:
#             Passengers  Passengers
# Month
# 1949-02-01       112.0         118
# 1949-03-01       118.0         132
# 1949-04-01       132.0         129
# 1949-05-01       129.0         121
# 1949-06-01       121.0         135
# ...                ...         ...
# 1960-08-01       622.0         606
# 1960-09-01       606.0         508
# 1960-10-01       508.0         461
# 1960-11-01       461.0         390
# 1960-12-01       390.0         432
#
# [143 rows x 2 columns]

# %%
n_vars = 1 if type(df) is list else df.shape[1]
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
for i in range(0, 1):
    cols.append(df.shift(-i))
# put it all together
agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)
list_for_forecast = agg.values

# %%
len(list_for_forecast)
# Out:
# 143

# %%
def decision_tree_forecast(train, testX):
    train = asarray(train)
    trainX, trainy = train[:, :-1], train[:, -1]
    model = DecisionTreeRegressor(random_state=0)
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
def random_forest_forecast(train, testX):
    train = asarray(train)
    trainX, trainy = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]
history
# Out:
# [array([112., 118.]),
#  array([118., 132.]),
#  array([132., 129.]),
#  array([129., 121.]),
#  array([121., 135.]),
#  array([135., 148.]),
#  array([148., 148.]),
#  array([148., 136.]),
#  array([136., 119.]),
#  array([119., 104.]),
#  array([104., 118.]),
#  array([118., 115.]),
#  array([115., 126.]),
#  array([126., 141.]),
#  array([141., 135.]),
#  array([135., 125.]),
#  array([125., 149.]),
#  array([149., 170.]),
#  array([170., 170.]),
#  array([170., 158.]),
#  array([158., 133.]),
#  array([133., 114.]),
#  array([114., 140.]),
#  array([140., 145.]),
#  array([145., 150.]),
#  array([150., 178.]),
#  array([178., 163.]),
#  array([163., 172.]),
#  array([172., 178.]),
#  array([178., 199.]),
#  array([199., 199.]),
#  array([199., 184.]),
#  array([184., 162.]),
#  array([162., 146.]),
#  array([146., 166.]),
#  array([166., 171.]),
#  array([171., 180.]),
#  array([180., 193.]),
#  array([193., 181.]),
#  array([181., 183.]),
#  array([183., 218.]),
#  array([218., 230.]),
#  array([230., 242.]),
#  array([242., 209.]),
#  array([209., 191.]),
#  array([191., 172.]),
#  array([172., 194.]),
#  array([194., 196.]),
#  array([196., 196.]),
#  array([196., 236.]),
#  array([236., 235.]),
#  array([235., 229.]),
#  array([229., 243.]),
#  array([243., 264.]),
#  array([264., 272.]),
#  array([272., 237.]),
#  array([237., 211.]),
#  array([211., 180.]),
#  array([180., 201.]),
#  array([201., 204.]),
#  array([204., 188.]),
#  array([188., 235.]),
#  array([235., 227.]),
#  array([227., 234.]),
#  array([234., 264.]),
#  array([264., 302.]),
#  array([302., 293.]),
#  array([293., 259.]),
#  array([259., 229.]),
#  array([229., 203.]),
#  array([203., 229.]),
#  array([229., 242.]),
#  array([242., 233.]),
#  array([233., 267.]),
#  array([267., 269.]),
#  array([269., 270.]),
#  array([270., 315.]),
#  array([315., 364.]),
#  array([364., 347.]),
#  array([347., 312.]),
#  array([312., 274.]),
#  array([274., 237.]),
#  array([237., 278.]),
#  array([278., 284.]),
#  array([284., 277.]),
#  array([277., 317.]),
#  array([317., 313.]),
#  array([313., 318.]),
#  array([318., 374.]),
#  array([374., 413.]),
#  array([413., 405.]),
#  array([405., 355.]),
#  array([355., 306.]),
#  array([306., 271.])]

# %%
train.dtype(list())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train.dtype(list())
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable

# %%
predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = random_forest_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

error = mean_absolute_error(test[:, -1], predictions)
print("Random Forest error: ", error)
# Out:
# Random Forest error:  46.33889239552963

# %%
print("Random Forest metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Random Forest metrics:
# RMSE: 55.2427167699636
# MAPE: 0.10895338078382895
# MAE: 46.33889239552963
# R2:  0.5030866645060498

# %%
fig = plt.figure(figsize=(20, 9))
plt.plot(test[:, -1], label='Original data')
plt.plot(predictions, label='Random Forest')
plt.legend(fontsize="20")
plt.title('Airline passengers by month')
plt.ylabel('Total passengers', fontsize="20")
plt.xlabel('Month', fontsize="20")
plt.show()

# %%
predictions = list()
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = decision_tree_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

# %%
print("Decision Forest metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Decision Forest metrics:
# RMSE: 65.29403666867132
# MAPE: 0.12270617535711836
# MAE: 52.1530612244898
# R2:  0.3058111520951716

# %%
fig = plt.figure(figsize=(20, 9))
plt.plot(test[:, -1], label='Original data')
plt.plot(predictions, label='Decision Tree')
plt.legend(fontsize="20")
plt.title('Airline passengers by month')
plt.ylabel('Total passengers', fontsize="20")
plt.xlabel('Month', fontsize="20")
plt.show()

# %% [markdown]
# ## Детекция аномалий с помощью isolated forest

# %%
from sklearn.ensemble import IsolationForest

# %%
# аналогичным образом загружаем данные о пассажирах
pas = pd.read_csv('data/passengers.csv')
# неподходящий формат данных приводим к тому, с которым Pandas может работать
pas['Month'] = pd.to_datetime(passengers['Month'])
# также устанавливаем индекс и сортируем
pas
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %%
model = IsolationForest(contamination=0.004)
model.fit(pas[['Passengers']])
# Out:
# IsolationForest(contamination=0.004)

# %%
pas['outliers'] = pd.Series(model.predict(pas[['Passengers']])).apply(lambda x: 'yes' if (x == -1) else 'no' )

# %%
pas.query('outliers=="yes"')
# Out:
#          Month  Passengers outliers
# 138 1960-07-01         622      yes

# %%
fig = px.scatter(pas.reset_index(), x='Month', y='Passengers', color='outliers')
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# ## Самостоятельная работа
#
# **Задание 1: Учет сезонности (больше лагов)**
# В нашем прошлом примере мы брали сдвиг всего на один месяц (`lag = 1`). В данных авиаперевозок есть очевидная годовая сезонность.
# Измените код так, чтобы модель смотрела на 12 предыдущих месяцев одновременно. Сформируйте выборку, обучите `RandomForest` с помощью функции `random_forest_forecast` и выведите метрики. Сравните, как изменились результаты.

# %%
cols = []
for i in range(12, 0, -1):
    cols.append(df.shift(i))
cols.append(df.shift(0))

agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)
list_for_forecast = agg.values

predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:]
history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = random_forest_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

print("Random Forest (12 lags) metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Random Forest (12 lags) metrics:
# RMSE: 33.66452885093679
# MAPE: 0.06270880191789518
# MAE: 26.690533333333335
# R2:  0.8056155838917989

# %% [markdown]
# **Задание 2: Сравнение деревьев с «глупым» бейзлайном (Naive Forecast)**
# Чтобы понимать, насколько вообще полезно применять Random Forest, нужен ориентир (baseline). Напишите простую «наивную» модель: в качестве прогноза на следующий шаг берется просто значение предыдущего шага ($\hat{y}_t = y_{t-1}$).
# Сравните $R^2$ и $MAE$ наивного прогноза с вашим лесом из Задания 1.

# %%
y_naive = test[:, -2]

r2_naive = r2_score(test[:, -1], y_naive)
mae_naive = mean_absolute_error(test[:, -1], y_naive)

print("MAE:", mae_naive)
print("R2: ", r2_naive)
# Out:
# MAE: 40.977777777777774
# R2:  0.59033250438754

# %% [markdown]
# **Задание 3: Чувствительность алгоритма поиска аномалий**
# В конце практики мы использовали алгоритм `IsolationForest` для поиска аномалий с крайне низким параметром `contamination=0.004`.
# Измените этот параметр на `0.05` (поиск 5% самых аномальных периодов), обучите модель заново и отрисуйте график с новыми подсвеченными точками. Как поменялась картина, какие теперь месяцы считаются "нетипичными"?

# %%
model = IsolationForest(contamination=0.05, random_state=42)
model.fit(pas[['Passengers']])

pas['outliers'] = pd.Series(model.predict(pas[['Passengers']])).apply(lambda x: 'yes' if (x == -1) else 'no')
fig = px.scatter(pas.reset_index(), x='Month', y='Passengers', color='outliers',
                 title='Isolation Forest Anomalies (contamination=0.05)')
fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# C contamination=0.05 помимо июля 1960 года, нетипичными стали являться следуюущие месяца

# %%
pas.query('outliers=="yes"')
# Out:
#          Month  Passengers outliers
# 10  1949-11-01         104      yes
# 114 1958-07-01         491      yes
# 126 1959-07-01         548      yes
# 127 1959-08-01         559      yes
# 137 1960-06-01         535      yes
# 138 1960-07-01         622      yes
# 139 1960-08-01         606      yes
# 140 1960-09-01         508      yes
